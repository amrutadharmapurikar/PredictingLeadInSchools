# %%
import csv

# %%
f = open('/Users/23amrutad/Downloads/addresses.csv', 'r')

# %%
file = csv.DictReader(f)

# %%
addresses_list = []

# %%
for ad in f:
    addresses_list.append(ad)

# %%
beginning_url = 'https://maps.googleapis.com/maps/api/geocode/json?address='
key = 'AIzaSyByW1BRve88yIMrnbHOGFUTg6SExr_afIg'

# %%
import requests

# %%
output = []
import json

# %%
for ad in addresses_list:
    newAd = ad[0:-2].split()
    newNewAd = beginning_url
    for part in newAd:
        newNewAd = newNewAd + part + '+'
    newNewAd = newNewAd[0: -1]
    newNewAd = newNewAd + '&key=' + key
    x = requests.get(newNewAd)
    a = x.text
    #b = json.loads(a)
    #c = b["results"][0]
    #d = c["geometry"]
    #e = d["location"]
    output.append(a)
    print("-")
# Out:
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# ...

# %%
#s = json.dumps(output)
#f=open('/Users/23amrutad/Desktop/school_latlong.json', 'w')
#f.write(s)
#f.close()

# %%
f1 = open("/Users/23amrutad/Desktop/school_latlong.json", "r")
text = f1.read()
f1.close()

# %%
l = json.loads(text)

# %%
tot_info = []
count = 0

# %%
for i in range(len(l)):
    #print(count)
    count += 1
    a = json.loads(l[i])
    #if a == None:
    #    print("ouch")
    #else:
    #   print("yay")
    if len(a["results"]) == 0:
        print(a)
        continue
    b = a["results"][0]
    c = b["address_components"]
    d = b["geometry"]
    lat = d["location"]["lat"]
    long = d["location"]["lng"]
    info = [addresses_list[i], lat, long]
    tot_info.append(info)
# Out:
# {'results': [], 'status': 'ZERO_RESULTS'}
# {'results': [], 'status': 'ZERO_RESULTS'}
# {'results': [], 'status': 'ZERO_RESULTS'}
# {'results': [], 'status': 'ZERO_RESULTS'}
# {'results': [], 'status': 'ZERO_RESULTS'}
# {'results': [], 'status': 'ZERO_RESULTS'}
# {'results': [], 'status': 'ZERO_RESULTS'}
# {'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account', 'results': [], 'status': 'REQUEST_DENIED'}
# {'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account', 'results': [], 'status': 'REQUEST_DENIED'}
# {'results': [], 'status': 'ZERO_RESULTS'}
# {'results': [], 'status': 'ZERO_RESULTS'}
# {'results': [], 'status': 'ZERO_RESULTS'}

# %%
print(len(tot_info))
# Out:
# 1930

# %%
from math import cos, asin, sqrt, pi

# %%
import pandas as pd

# %%
print(len(tot_info))
# Out:
# 1930

# %%
idx = []
cols = []
for i in range(len(tot_info)):
    idx.append(i)
    cols.append(i)

# %%
df = pd.DataFrame(index=idx, columns=cols)

# %%
def distance(lat1, lon1, lat2, lon2):
    p = pi/180
    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p) * cos(lat2*p) * (1-cos((lon2-lon1)*p))/2
    return 12742 * asin(sqrt(a))

# %%
for i in range(len(tot_info)):
    for j in range(len(tot_info)):
        d = distance(tot_info[i][1], tot_info[i][2], tot_info[j][1], tot_info[j][2])
        df.at[i, j] = d

# %%
print(df)
# Out:
#             0           1           2           3           4           5     \
# 0            0.0   88.004952  157.618539  152.123388  142.523591   99.210745
# 1      88.004952         0.0   81.584338   79.993009   56.623264   59.934464
# 2     157.618539   81.584338         0.0    9.896537   37.092175   67.900577
# 3     152.123388   79.993009    9.896537         0.0   42.158366   59.649983
# 4     142.523591   56.623264   37.092175   42.158366         0.0   73.465148
# ...          ...         ...         ...         ...         ...         ...
# 1925  103.930865  188.011237  243.248572   235.46974  237.644031  175.919354
# 1926  133.724739    51.70438   31.374489    33.11335    14.81614   58.952816
# 1927  142.439182   56.033567   39.560128   44.704653    2.548781   75.072456
# 1928  122.161599   92.833244   76.728279    66.88534   95.406905   33.143718
# 1929   89.301872   24.801496  101.477022  101.378787   70.805869   84.270959
#
# ...

# %%
print(df[500][600])
# Out:
# 125.33322479344382

# %%
a = tot_info[500]
b = tot_info[600]

# %%
d = distance(a[1], a[2], b[1], b[2])

# %%
print(d)
# Out:
# 125.33322479344382

# %%
print(a[0])
print(b[0])
# Out:
# WHITE MOUNTAIN WALDORF SCHOOL      CONWAY       NH,
#
# CARLA'S FAMILY DAY CARE MERRIMACK NH,

# %%
df.to_csv("/Users/23amrutad/Desktop/distance_between_schools.csv")
